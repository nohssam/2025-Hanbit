# %% [markdown]
# ### 이미지를 위한 인공 신경망

# %%
from IPython.display import Image, display
display(Image(filename="data/img24.png", width=600, height=400))

# %%
display(Image(filename="data/img25.png", width=600, height=400))

# %%
display(Image(filename="data/img26.png", width=600, height=400))

# %%
display(Image(filename="data/img27.png", width=600, height=400))

# %%
display(Image(filename="data/img28.png", width=600, height=400))

# %%
display(Image(filename="data/img29.png", width=600, height=400))

# %%
display(Image(filename="data/img30.png", width=600, height=400))

# %%
display(Image(filename="data/img31.png", width=600, height=400))

# %%
display(Image(filename="data/img32.png", width=600, height=400))

# %%
display(Image(filename="data/img33.png", width=600, height=400))

# %%
display(Image(filename="data/img34.png", width=600, height=400))

# %%
display(Image(filename="data/img35.png", width=600, height=400))

# %%
display(Image(filename="data/img36.png", width=600, height=400))

# %%
display(Image(filename="data/img37.png", width=600, height=400))

# %%
display(Image(filename="data/img38.png", width=600, height=400))

# %%
display(Image(filename="data/img39.png", width=600, height=400))

# %%
display(Image(filename="data/img40.png", width=600, height=400))

# %%
display(Image(filename="data/img41.png", width=600, height=400))

# %%
display(Image(filename="data/img42.png", width=600, height=400))

# %%
display(Image(filename="data/img43.png", width=600, height=400))

# %%
display(Image(filename="data/img44.png", width=600, height=400))

# %%
display(Image(filename="data/img45.png", width=600, height=400))

# %%
display(Image(filename="data/img46.png", width=600, height=400))

# %%
display(Image(filename="data/img47.png", width=600, height=400))
